# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('data/Data.csv')
cat=pd.read_csv('data/CategoryNames.csv')
result=pd.DataFrame({'Count' : df.groupby( [ 'CategoryId'] ).size()}).reset_index()
df=df.groupby(['CategoryId']).sum().reset_index()
result=pd.merge(result,df,on='CategoryId')
result=pd.merge(result,cat,on='CategoryId')
result['averageCount']=(result['ViewCount']/result['Count']).astype(int)
result.plot.barh(x='Title',y='averageCount')
plt.show()
result.to_csv('Analysis/analysis_5.csv', sep=',', encoding='utf-8',index=False)
# Out:
#     CategoryId  Count    ViewCount                  Title  averageCount
# 0            1   2598   6278487620       Film & Animation       2416661
# 1            2    147      5018621       Autos & Vehicles         34140
# 2           10   1452  19478635534                  Music      13415038
# 3           15    103   1228125876         Pets & Animals      11923552
# 4           17    660    204346416                 Sports        309615
# 5           19      3       267409        Travel & Events         89136
# 6           20   1959   3041578259                 Gaming       1552617
# 7           22   3182   2109939978         People & Blogs        663086
# 8           23   1348   1104458361                 Comedy        819331
# 9           24   3482  15688088608          Entertainment       4505482
# 10          25   1089   5021747738        News & Politics       4611338
# 11          26    246    272686747          Howto & Style       1108482
# 12          27    427   2264299567              Education       5302809
# 13          28    258   1152454754   Science & Technology       4466878
# 14          29    422    304291236  Nonprofits & Activism        721069
