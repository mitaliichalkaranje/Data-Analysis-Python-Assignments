# %%
import requests

for k in range(1,100):
    results = requests.get(url="https://api.stackexchange.com/2.2/questions?tagged=python;pandas&page=1&pagesize=100&site=stackoverflow&key=Qbw)9y9ZFui61wxBzFU7mQ((") 
    raw_data=results.json()
    d={}
    for data in raw_data['items']:
        d=data
    sleep(0.5)
# Out:
# {'has_more': True, 'quota_max': 10000, 'items': [{'link': 'http://stackoverflow.com/questions/40354235/why-do-i-get-0-when-dividing-two-numbers', 'title': 'Why do I get 0 when dividing two numbers?', 'last_activity_date': 1477977022, 'view_count': 26, 'last_edit_date': 1477976447, 'is_answered': False, 'answer_count': 2, 'score': 0, 'question_id': 40354235, 'tags': ['python', 'pandas'], 'owner': {'user_id': 5776769, 'display_name': 'zorny', 'profile_image': 'https://www.gravatar.com/avatar/b1890047cccfd4aaff358ebdc98ee236?s=128&d=identicon&r=PG&f=1', 'reputation': 50, 'accept_rate': 45, 'user_type': 'registered', 'link': 'http://stackoverflow.com/users/5776769/zorny'}, 'creation_date': 1477975174}, {'link': 'http://stackoverflow.com/questions/40353555/backreference-in-pandas-str-replace', 'title': 'Backreference in Pandas str.replace', 'answer_count': 0, 'last_activity_date': 1477971892, 'score': 0, 'creation_date': 1477969309, 'question_id': 40353555, 'owner': {'user_id': 2369867, 'display_name': 'Maven', 'profile_image': 'https://www.gravatar.com/avatar/28ac505c39a1d4c37ffe6fc8f8c24e36?s=128&d=identicon&r=PG&f=1', 'reputation': 345, 'accept_rate': 33, 'user_type': 'registered', 'link': 'http://stackoverflow.com/users/2369867/maven'}, 'tags': ['python', 'pandas'], 'view_count': 13, 'is_answered': False}, {'link': 'http://stackoverflow.com/questions/40353519/how-to-apply-custom-function-to-pandas-data-frame-for-each-row', 'title': 'How to apply custom function to pandas data frame for each row', 'last_activity_date': 1477971212, 'view_count': 15, 'last_edit_date': 1477970652, 'accepted_answer_id': 40353653, 'is_answered': True, 'answer_count': 2, 'score': 0, 'question_id': 40353519, 'tags': ['python', 'pandas'], 'owner': {'user_id': 5776769, 'display_name': 'zorny', 'profile_image': 'https://www.gravatar.com/avatar/b1890047cccfd4aaff358ebdc98ee236?s=128&d=identicon&r=PG&f=1', 'reputation': 50, 'accept_rate': 45, 'user_type': 'registered', 'link': 'http://stackoverflow.com/users/5776769/zorny'}, 'creation_date': 1477968990}, {'link': 'http://stackoverflow.com/questions/40344047/pandas-0-18-vs-0-12-performance', 'title': 'Pandas 0.18 vs 0.12 performance', 'last_activity_date': 1477971206, 'view_count': 25, 'last_edit_date': 1477925492, 'is_answered': False, 'answer_count': 1, 'score': 1, 'question_id': 40344047, 'tags': ['python', 'performance', 'pandas', 'dataframe'], 'owner': {'user_id': 5831212, 'link': 'http://stackoverflow.com/users/5831212/giuliano', 'profile_image': 'https://www.gravatar.com/avatar/d964f5b8978487516de4de2a028d4249?s=128&d=identicon&r=PG&f=1', 'reputation': 18, 'display_name': 'Giuliano', 'user_type': 'registered'}, 'creation_date': 1477923536}, {'link': 'http://stackoverflow.com/questions/40353695/prediction-of-stock-prices-using-arima', 'title': 'Prediction of Stock Prices using ARIMA', 'answer_count': 0, 'last_activity_date': 1477970524, 'score': 0, 'creation_date': 1477970524, 'question_id': 40353695, 'owner': {'user_id': 5400974, 'display_name': 'Beginner1111', 'profile_image': 'https://www.gravatar.com/avatar/92a8ccd79a3834fe17322de657279477?s=128&d=identicon&r=PG&f=1', 'reputation': 9, 'accept_rate': 75, 'user_type': 'registered', 'link': 'http://stackoverflow.com/users/5400974/beginner1111'}, 'tags': ['python', 'pandas', 'time-series', 'statsmodels', 'google-prediction'], 'view_count': 11, 'is_answered': False}, {'link': 'http://stackoverflow.com/questions/40352844/how-can-i-reshape-a-pandas-dataframe-to-show-if-certain-values-in-a-column-are-p', 'title': 'How can I reshape a Pandas DataFrame to show if certain values in a column are present by day?', 'answer_count': 1, 'last_activity_date': 1477968791, 'score': 0, 'creation_date': 1477962973, 'question_id': 40352844, 'owner': {'user_id': 5063945, 'link': 'http://stackoverflow.com/users/5063945/franco', 'profile_image': 'https://lh5.googleusercontent.com/-jcORmBAcwwQ/AAAAAAAAAAI/AAAAAAAADFM/x0zdxEl7LHQ/photo.jpg?sz=128', 'reputation': 9, 'display_n ...
