# %%
import glob 
import os,json
import pandas as pd  

first=0
third=0
files=glob.glob('C:/Fall 2016/Data Analysis using Python/Assignment/Assignment_01/jsons/*.json')   
for file in files:
    name= os.path.splitext(os.path.basename(file))[0]
    temp={}
    with open(file) as f:
        first=0
        third=0
        data=f.read()
        json_data=json.loads(data)
        if json_data.get('retargetingSegments'):
            for segments in json_data['retargetingSegments']:
                seg=segments['segmentUid']
                if seg.startswith("0"):
                    first+=1
                else:
                    if seg.startswith("1"):
                        third+=1
            temp['first']=first
            temp['third']=third
            dictionary[name]={}
            dictionary[name].update(temp)
print(dictionary)
# Out:
# {'R0bRPwwc1Bj8SG5': {'third': 0, 'first': 192}, 'RhomxVAg1BKCXM5': {'third': 0, 'first': 4}, 'rlCDZMai1ALhom5': {'third': 369, 'first': 56}, 'wfwUF5Vd1BGFgr2': {'third': 4, 'first': 6}, 'Qpu2EAfQ1BMm5J2': {'third': 0, 'first': 4}, 'qaYSpRdq1BqDGF5': {'third': 444, 'first': 26}, 'W9GfOapB1BKu0w5': {'third': 14, 'first': 6}, 'zRZbEMBH1BAQxr5': {'third': 262, 'first': 173}, 'AjnCxTwv1BMutG2': {'third': 0, 'first': 4}, 'Qve9aYp91zzUnC5': {'third': 0, 'first': 159}, 'WMW6SIZe1BKLSo5': {'third': 11, 'first': 5}, 'WpUidKQk1BKIT25': {'third': 13, 'first': 8}, 'AdjWlMHv1A8vM55': {'third': 14, 'first': 125}, 'wUBFp9ND1B2O7H5': {'third': 330, 'first': 132}, 'ZnrJ1QXr1AuC3x5': {'third': 0, 'first': 2}, 'Wa8QvwxH1A8S625': {'third': 321, 'first': 64}, 'ZuQO68HJ1BC5bh5': {'third': 0, 'first': 10}, 'wWVrBJXs1BL6uj5': {'third': 0, 'first': 3}, 'rMXdZsXg1BERmv5': {'third': 279, 'first': 206}, 'rUcoRMHx1Ak9SX5': {'third': 0, 'first': 171}, 'qQbfcvFi1B2krk5': {'third': 2609, 'first': 305}, 'ANuFI3wm1BM9
# ...
